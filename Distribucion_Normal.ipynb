# %% [markdown]
# <a href="https://colab.research.google.com/github/JonatanMontoya/Tareas/blob/main/Distribucion_Normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Montoya López Jonatan Emmanuel
from random import random
import matplotlib.pyplot as plt

def nor(mu,s):
    suma=0
    l=[]
    for i in range(12):
        suma=suma+random()
        x=mu + s * (suma - 6)
    return x 

l1=[]

for i in range(1000):
    l1.append(nor(180,15))
print(l1, len(l1))

plt.hist(l1, color='black', edgecolor='grey')
plt.title('Histograma')
plt.show()
# Out:
# [190.13165798729034, 179.01902032836514, 181.0594080004716, 175.03737476950084, 178.2350713541011, 167.5633714599937, 201.22234608990513, 183.74999958618875, 157.0651424892584, 155.00475910611843, 199.4603205323038, 181.80142867390066, 188.17069166189424, 174.623032660176, 178.3825788519405, 212.78386315789083, 172.523197850166, 191.03571631526938, 187.3187138276842, 128.83957213324248, 190.38204919685143, 178.41410126905348, 157.67563042938838, 210.90446932322376, 184.71636781551842, 176.772501192787, 181.48262053565534, 151.32031446283548, 168.80410917772514, 196.18001239484124, 176.78524044543784, 165.28907978065462, 187.62230117830947, 203.00560778658468, 182.67648256893636, 166.07866017896748, 163.16365910473434, 154.02105831709537, 184.20869714942793, 153.1335483523244, 205.11452691362945, 185.91832740549785, 180.21945631764004, 186.78026406162556, 186.38157501186677, 201.927463986438, 181.85048516463752, 195.45218094678032, 168.84265360338176, 180.8147570779745, 183.7802052734
# ...
